# %% [markdown]
# ## Importing Libraries in python

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Dataset in module

# %%
titanic_df = pd.read_csv('TitanicDataset.csv')

# %% [markdown]
# ## Read the Dataset

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic_df.sample()
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 189          190         0       3  Turcin, Mr. Stjepan  male  36.0      0
#
#      Parch  Ticket    Fare Cabin Embarked
# 189      0  349247  7.8958   NaN        S

# %% [markdown]
# ## Check the Dataset Shape

# %%
titanic_df.shape
# Out:
# (891, 12)

# %% [markdown]
# #### observation: There are 891 people and 12 columns are shown us information

# %% [markdown]
# ## Check the Information about dataset

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #### observation: There are 12 columns inside the dataset categorical columns are 5 and other numerical

# %% [markdown]
# ## Check the columns inside the dataset

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# #### Obser:There are 12 columns inside the dataset

# %% [markdown]
# ## Check the Null values and  Missing values

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# #### observation:
# #### There are 177 null values in the age column,687 in Cabin, 2 in Embarked
# ##### since the cabin column is not of much use and contains a lot of null values so we will drop it.

# %% [markdown]
# ## Drop the Cabin columns

# %%
titanic_df.drop(columns='Cabin',axis=1,inplace=True)

# %% [markdown]
# ## Imputing missing values to Age columns

# %%
titanic_df['Age'].isnull().sum()
# Out:
# 177

# %%
titanic_df['Age'].fillna(titanic_df['Age'].mean(),inplace=True)

# %%
titanic_df['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Fill all The missing valuess with respect the mean of Age col

# %% [markdown]
# ## Imputing missing values to Embarked

# %%
titanic_df['Embarked'].isnull().sum()
# Out:
# 2

# %%
titanic_df['Embarked'].fillna(titanic_df['Embarked'].mode()[0],inplace=True)

# %%
titanic_df['Embarked'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### obs: Imputing all Missing values in the dataset

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## Check Duplicate Values

# %%
titanic_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### There is no duplicate values inside the dataset

# %% [markdown]
# ## Check the Survival counts

# %%
titanic_df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# ## Visualize of Survival Pepole

# %% [markdown]
# ## Plot the CountPlot

# %%
sns.countplot(x='Survived',data=titanic_df,palette='viridis',)
plt.xlabel("Survival status")
plt.ylabel("Number of people")
plt.xticks(ticks=[0,1],labels=['Not survived','survived'])
plt.show()

# %% [markdown]
# ## Pie chart

# %%
plt.pie(titanic_df['Survived'].value_counts(),explode=[0,0.04],autopct="%1.2f%%",labels=['Not survived','Survived'])
plt.title("Survival of people")
plt.show()

# %% [markdown]
# ## Visualization of people survived from different gender

# %%
titanic_df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
sns.countplot(x='Sex',data=titanic_df,palette='viridis',)
plt.xlabel("Gender")
plt.ylabel("Number of people")
plt.show()

# %%
sns.countplot(x='Survived',hue='Sex',data=titanic_df,palette='deep')
plt.xlabel("Survival status")
plt.ylabel("Number of people")
plt.xticks(ticks=[0,1],labels=['Not survived','survived'])
plt.show()

# %%
titanic_df[titanic_df['Sex'] == 'male'].Survived.groupby(titanic_df.Survived).count().plot(kind='pie',
figsize=(3, 6),explode=[0,0.05],autopct='%1.1f%%',labels=["Not survived","Survived"])
plt.ylabel("")
plt.title("Male survival rate")
plt.show()

# %%
titanic_df[titanic_df['Sex'] == 'female'].Survived.groupby(titanic_df.Survived).count().plot(kind='pie',
figsize=(3, 6),explode=[0,0.05],autopct='%1.1f%%',labels=["Not survived","Survived"])
plt.ylabel("")
plt.title("Female survival rate")
plt.show()

# %% [markdown]
# #### Observation:
# #### Survival rate was female was much higher in comparison to male

# %% [markdown]
# ## visualizing the population of different passenger class

# %%
sns.countplot(x='Pclass',data=titanic_df,palette='viridis',)
plt.xlabel("Pclass")
plt.ylabel("Number of people")
plt.show()

# %% [markdown]
# ## Visualization of people survived from different passenger class

# %%
sns.countplot(x='Survived',hue='Pclass',data=titanic_df,palette='viridis',)
plt.xlabel("Survival status")
plt.ylabel("Number of people")
plt.xticks(ticks=[0,1],labels=['Not survived','survived'])
plt.show()

# %%
sns.catplot(x = 'Pclass', hue = 'Survived', col = 'Sex', kind = 'count', data =titanic_df,palette='viridis' )
plt.tight_layout()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9084\1249035516.py:2: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# #### Observation:
# the population of p class 3 has highest least survival rate
# Males from P class 3 had the least survival rate

# %% [markdown]
# ## Visualization of people survived from different Embarkment

# %%
sns.countplot(x='Embarked',data=titanic_df,palette='coolwarm',)
plt.xlabel("Embarked")
plt.ylabel("Number of people")
plt.show()

# %%
sns.countplot(x='Survived',hue='Embarked',data=titanic_df,palette='viridis',)
plt.xlabel("Survival status")
plt.ylabel("Number of people")
plt.xticks(ticks=[0,1],labels=['Not survived','survived'])
plt.show()

# %% [markdown]
# observation: S had least of survived rate

# %% [markdown]
# ## Distribution of Fare and age

# %%
fig,axes = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(titanic_df['Fare'], kde=True,ax=axes[0])
sns.histplot(titanic_df['Age'].dropna(),kde=True,ax=axes[1])
plt.show()

# %% [markdown]
# ## Visualizing survival rate in different age category

# %%
titanic_df['AGE_Category']= pd.cut(titanic_df.Age,[0,25,45,65,95],
                              labels = ['Below 25',"25-35","35-45","45-90"])

# %% [markdown]
# Check which age group had more pople

# %%
titanic_df['AGE_Category'].value_counts(normalize=True).plot.pie(autopct ='%1.2f%%')
plt.show()

# %%
cut_points = [0, 5, 12, 18, 35, 60, 100]
label_names = ['Infant', 'Child', 'Teenager', 'Young Adult', 'Adult', 'Senior']

# Create the "Age_categories" column
titanic_df['Age_categories'] = pd.cut(titanic_df['Age'], bins=cut_points, labels=label_names, right=False)

# Create a new DataFrame with survival rates by age category
age_cat_pivot = titanic_df.groupby('Age_categories')['Survived'].mean().reset_index()

# Plotting using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Age_categories', y='Survived', data=age_cat_pivot, palette='viridis')

# Customize the plot
plt.title('Survival Rates by Age Category')
plt.xlabel('Age Category')
plt.ylabel('Survival Rate')
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# obs: Young Adult had least survival rate

# %% [markdown]
# ## Checking for correlation

# %%
titanic_df.replace({'Sex':{'male':1,'female':0},'Embarked':{'S':0,'C':1,'Q':2}},inplace=True)

# %%
df_num = titanic_df[['Fare','Parch','SibSp','Age','Sex','Pclass','Embarked','Survived']]

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_num.corr(), annot=True, cmap="RdYlGn", fmt=".2f", annot_kws={"size": 10})
plt.show()

# %% [markdown]
# Observation:
#
# Fare, sex, Pclass, Embarked has correlation with survived column

# %% [markdown]
# ## Conclusion:
# ---Gender Disparity: The survival rate among females was significantly higher compared to males. This observation aligns with the "women and children first" protocol followed during the Titanic disaster, reflecting societal norms of the time prioritizing women's and children's safety.
#
# ---Passenger Class Disparity: Although the population of passengers in Class 3 was the highest, they had the lowest survival rate. This indicates a potential correlation between socio-economic status and survival, with passengers in higher classes likely having better access to lifeboats and other resources during the evacuation.
#
# ---Gender and Passenger Class Interaction: Further analysis reveals that males from Class 3 had the lowest survival rate. This suggests a compounded effect of gender and socio-economic status, where male passengers in the lower classes faced the highest risk of not surviving the disaster.
#
# ---Age Factor: Young adults had the least survival rate, indicating that age played a role in survival outcomes. This could be attributed to the "women and children first" policy, where younger individuals were given priority during the evacuation.
#
# ---Correlation with Survived Column: The variables fare, sex, passenger class (Pclass), and embarkation point (Embarked) show correlations with the survival outcome. This reinforces the importance of these factors in determining survival chances during the Titanic disaster.

# %% [markdown]
# Thank You
